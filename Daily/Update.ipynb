# 2022-03-11      7.48    49.40  63.14    48.02   53.68  72.21  40081.679688
# 2022-03-12     16.06    31.20  68.53    44.10   47.58  61.42  39308.597656
# 2022-03-13     10.34    29.90  61.60    44.10   54.90  61.42  39209.351562
# 2022-03-14     10.56    52.65  67.76    29.89   49.41  68.06  39742.500000
# 2022-03-15     14.52    50.05  56.98    40.18   53.07  68.06  39794.628906
# 2022-03-16      8.80    59.15  65.45    45.08   54.90  63.91  41465.453125
# 2022-03-17     11.44    58.50  66.22    32.34   53.68  58.10  41287.535156
# 2022-03-18     10.12    48.10  63.14    36.26   48.19  58.10  42195.746094
# 2022-03-19     12.10    24.05  61.60    43.61   50.02  57.27  42316.554688
# 2022-03-20     15.84    23.40  66.22    44.10   52.46  56.44  42241.164062
# 2022-03-21     10.34    53.95  63.91    40.18   52.46  68.06  41454.410156
# 2022-03-22     11.22    60.45  70.84    40.67   51.85  74.70  43124.707031
# 2022-03-23      9.68    42.90  71.61    48.51   55.51  67.23  42893.507812
# 2022-03-24     11.00    49.40  77.00    30.38   51.85  63.91  44131.855469
# 2022-03-25     10.34    53.30  60.83    42.14   46.97  58.93  44999.492188
# 2022-03-26      8.80    37.05  73.92    37.73   52.46  53.12  44735.996094
# 2022-03-27     16.28    24.05  64.68    34.79   52.46  52.29  46827.546875
# 2022-03-28     17.38    47.45  64.68    24.01   53.68  77.19  48086.835938
# 2022-03-29     14.08    65.00  65.45    32.83   56.73  83.00  48022.289062
# 2022-03-30     22.00    59.15  74.69    39.69   56.12  60.59  47655.148438
# 2022-03-31     13.64    55.25  70.07    31.85   57.95  57.27  47512.027344

# %% [markdown]
# ## Get today's date

# %%
from datetime import datetime

# %%
today = datetime.today()
stop_year = today.year
stop_mon = today.month
stop_day = today.day

# %% [markdown]
# ## Get start date

# %% [markdown]
# We will start from one month before the last data point.
# If the last data point is in April, we will fetch data starting from March until today.
# We will use March to calculate scale.

# %%
last_point = df.index[-1]
if last_point.to_pydatetime().month == 1:
    start_year = last_point.to_pydatetime().year - 1
    start_mon = 12
else:
    start_year = last_point.to_pydatetime().year
    start_mon = last_point.to_pydatetime().month - 1

# %% [markdown]
# ## Get keywords from file

# %%
import pickle

# %%
with open("raw_keywords", "rb") as fp:   # Unpickling
    raw_keywords = pickle.load(fp)

# %%
with open("exact_keywords", "rb") as fp:   # Unpickling
    exact_keywords = pickle.load(fp)

# %%
transform_dict = {exact_keywords[i] : raw_keywords[i] for i in range(len(exact_keywords))}
transform_dict
# Out:
# {'/m/05p0rrx': 'Bitcoin',
#  'Bitcoin Crash': 'Bitcoin Crash',
#  'Blockchain': 'Blockchain',
#  'Crisis': 'Crisis',
#  '/m/0vpj4_b': 'Cryptocurrency',
#  '/g/11gf8fjrxc': 'Nicehash',
#  '/m/03l5h': 'Hashing',
#  '/m/022l1f': 'GPU',
#  '/m/0132b8': 'GeForce',
#  '/m/053rd': 'mining',
#  '/m/0dr90d': 'Tesla'}

# %% [markdown]
# ## Pytrends - Getting New Data

# %%
import pytrends
from pytrends.request import TrendReq
from pytrends import dailydata
pytrend = TrendReq(hl='en-US', tz=360)
import time

# %%
df_list = []
for word in exact_keywords:
    thisword = dailydata.get_daily_data(word = word, start_year = start_year, start_mon = start_mon, stop_year = stop_year, stop_mon = stop_mon, verbose = False)
    thisword = thisword[thisword['isPartial'] == False]
    df_list.append(thisword[word])
    print(word + ' done\n')
    time.sleep(10)
# Out:
# /m/05p0rrx done
#
# Bitcoin Crash done
#
# Blockchain done
#
# Crisis done
#
# /m/0vpj4_b done
#
# /g/11gf8fjrxc done
#
# /m/03l5h done
#
# /m/022l1f done
#
# /m/0132b8 done
#
# /m/053rd done
#
# /m/0dr90d done

# %% [markdown]
# ## Debug

# %%
timeframe = f"{start_year}-{start_mon:02}-01 {stop_year}-{stop_mon:02}-{stop_day}"
timeframe
# Out:
# '2022-03-01 2022-06-25'

# %%
kw_list = ["Blockchain"]
#kw_list = ["Bitcoin"]
pytrend.build_payload(kw_list, cat=0, timeframe=timeframe, geo='US', gprop='')

# %%
pytrend.interest_over_time()
# Out:
#             Blockchain  isPartial
# date
# 2022-03-01          77      False
# 2022-03-02          73      False
# 2022-03-03          72      False
# 2022-03-04          57      False
# 2022-03-05          42      False
# ...                ...        ...
# 2022-06-20          52      False
# 2022-06-21          61      False
# 2022-06-22          66      False
# 2022-06-23          52      False
# 2022-06-24           0       True
#
# [116 rows x 2 columns]

# %%
df_trends = pd.concat(df_list, axis = 1)
df_trends.rename(columns = transform_dict, inplace = True)
df_trends
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df_trends = pd.concat(df_list, axis = 1)
#       2 df_trends.rename(columns = transform_dict, inplace = True)
#       3 df_trends
#
# NameError: name 'df_list' is not defined

# %% [markdown]
# ## Pytrends - Calculate Scaling Factor

# %%
original = df.loc[(df.index.month == start_mon) & (df.index.year == start_year)].drop(columns = ['Price'])

# %%
original

# %%
new = df_trends.loc[(df_trends.index.month == start_mon) & (df_trends.index.year == start_year)]

# %%
new

# %%
for keyword in original.columns:
    print(original[keyword] / new[keyword])

# %% [markdown]
# ## YFinance

# %%
import yfinance as yf

# %%
df_price = yf.Ticker('BTC-USD').history(period = '10y', interval = '1d')

# %%
df_price.index.names = ['date']

# %%
df_price = df_price['High'].to_frame().rename(columns = {'High' : 'Price'})

# %%
df_price

# %% [markdown]
# ## Join

# %%
new_data = pd.concat([df_trends, df_price], axis = 1, join = 'inner')

# %% [markdown]
# ## Inspect

# %%
df

# %%
new_data

# %%
dailydata.get_daily_data(word = 'Bitcoin', start_year = 2022, start_mon = 5, stop_year = 2022, stop_mon = 6)
