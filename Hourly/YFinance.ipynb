# %%
import yfinance as yf

# %%
df = yf.Ticker('BTC-USD').history(period = '2mo', interval = '1h')

# %%
df.index.name = 'time'

# %%
df
# Out:
#                                    Open          High           Low  \
# time
# 2022-04-19 02:00:00+00:00  40775.023438  40775.023438  40664.164062
# 2022-04-19 03:00:00+00:00  40654.601562  40750.195312  40648.042969
# 2022-04-19 04:00:00+00:00  40713.429688  40854.812500  40697.796875
# 2022-04-19 05:00:00+00:00  40846.906250  40858.507812  40691.160156
# 2022-04-19 06:00:00+00:00  40690.281250  40792.695312  40680.976562
# ...                                 ...           ...           ...
# 2022-06-18 22:00:00+00:00  18516.029297  18719.089844  18516.029297
# 2022-06-19 00:00:00+00:00  18996.687500  19109.523438  18956.490234
# 2022-06-19 01:00:00+00:00  18987.208984  19011.125000  18554.929688
# 2022-06-19 02:00:00+00:00  18516.654297  18535.517578  18422.453125
# 2022-06-19 02:30:00+00:00  18399.980469  18399.980469  18399.980469
#
#                                   Close     Volume  Dividends  Stock Splits
# time
# ...

# %%
df.to_csv('price.csv')
